# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# 1 image description usimg feature extraction

import requests
import openai

openai.api_key = "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"

def generate_image_description(image_url):
    response = requests.get(image_url)
    image = response.content

    prompt = (f"Describe the following image: {image_url}")

    completions = openai.Completion.create(
        engine="text-davinci-002",
        prompt=prompt,
        max_tokens=1024,
        n=1,
        stop=None,
        temperature=0.5,
    )

    message = completions.choices[0].text
    return message

# urls=['https://fsa.zobj.net/crop.php?r=hGTfzGMnqY_QtffznfajY0nl9HlLIrwhPL_WpgbpkhJ5Bh6pyTMk8oU96rnUybLdz60amDUvgnSx0lQv7G0cidus59dXzunywFItBxLePuEkKrAaNO-DzCsX9Lyycrps0KY93J3Mem6f_BEF2ohoNs8NNkpnsb8j68SoDGMdtfS1TOG3ZqZF--97uN0',
#       'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSvJycFftMKCe7DlgyRvmJYjpZHixpuquttBtiPmwBX&s',
#       'https://w0.peakpx.com/wallpaper/824/387/HD-wallpaper-video-game-lost-in-random-thumbnail.jpg',
#       'https://w0.peakpx.com/wallpaper/824/387/HD-wallpaper-video-game-lost-in-random-thumbnail.jpg']
# for i in urls:
#   print(generate_image_description(i))

descriptions = generate_image_description('https://1drv.ms/u/s!ArgzjLMJeSYfh10viNaJHyBEUgLr?e=RyqgbG')
print(descriptions)
# Out:
# A person is sitting on a dock with their feet in the water. The person has dark hair and is wearing a light-colored shirt. The background is a body of water with mountains in the distance.

# %%
# 2 funny caption generation model


import openai

# Use the GPT-3 model
openai.api_key = "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"
model_engine = "text-davinci-002"

def generate_text(prompt):
    completions = openai.Completion.create(
        engine=model_engine,
        prompt=prompt,
        max_tokens=100,
        n=1,
        stop=None,
        temperature=0.5,
    )

    message = completions.choices[0].text
    return message


# generated_text = generate_text("Create a funny caption for a new meme. The background picture is" + descriptions)
# print(generated_text)

# captions = []
for i in range(10):
    generated_text = generate_text("Create a funny caption for a new meme. The background picture is" + descriptions)
#     captions.append(generated_text)
    print(generated_text)
    
# print(captions)

# captions = []
# for i in range(10):
#     generated_text = generate_text("Create a funny caption for a new meme. The background picture is" + descriptions)
#     captions.append(generated_text)
# for i in range(10):
#     print((i+1),captions[i])
# Out:
# "When you realize you're about to graduate and still don't have a job."
#
#
# "When you're trying to enjoy your vacation but you're still thinking about work."
#
#
# "I'm not a morning person."
#
#
# "I'm not a morning person."
#
#
#
#
# "I'm not a morning person."
#
#
# "I'm not a morning person."
#
#
# "When you're trying to enjoy nature but you just can't stop thinking about work."
#
#
# "When you realize you're about to graduate and still don't have a job lined up."
#
#
# "When you're trying to enjoy nature but you're still thinking about that project due tomorrow."
#
#
# "When you're trying to enjoy your vacation but you keep getting calls from work"

# %%
# 2.1 NOT good text generation model

import openai

# Specify the API key for OpenAI
openai.api_key = "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"

# Define the prompt for text generation
prompt = ("Create a funny caption for a new meme. The background picture is" + descriptions)

# Choose a different GPT-3 model engine
model_engine = "text-curie-001"

# Request text generation from the OpenAI API using the chosen model engine
response = openai.Completion.create(
    engine=model_engine,
    prompt=prompt,
    max_tokens=100,
    n=1,
    stop=None,
    temperature=0.5,
)

# Print the generated text
print(prompt)
generated_text = response["choices"][0]["text"]
print(generated_text)
# Out:
# Create a funny caption for a new meme. The background picture is
#
# A man and woman are standing in front of a large, white building. They are both smiling and holding hands.
#  The text reads, "
#
# We're moving to New York!
#
# We're moving to New York!
#
# We're moving to New York!
#
# We're moving to New York!
#
# We're moving to New York!
#
# We're moving to New York!
#
# We're moving to New York!
#
# We're moving to New York!
#
# We're moving to New York!
#
# We're moving to New York!
#
# We're moving

# %%
def drawTextWithOutline(text, x, y):
    draw.text((x-2, y-2), text,(0,0,0),font=font)
    draw.text((x+2, y-2), text,(0,0,0),font=font)
    draw.text((x+2, y+2), text,(0,0,0),font=font)
    draw.text((x-2, y+2), text,(0,0,0),font=font)
    draw.text((x, y), text, (255,255,255), font=font)
    return

def drawText(text, pos):
    text = text.upper()
    w, h = draw.textsize(text, font) # measure the size the text will take

    lineCount = 1
    if w > img.width:
        lineCount = int(round((w / img.width) + 1))

    lines = []
    if lineCount > 1:

        lastCut = 0
        isLast = False
        for i in range(0,lineCount):
            if lastCut == 0:
                cut = int((len(text) / lineCount) * i + 0.5)
            else:
                cut = lastCut

            if i < lineCount-1:
                nextCut = int((len(text) / lineCount) * (i+1) + 0.5)
            else:
                nextCut = len(text)
                isLast = True

            # make sure we don't cut words in half
            if not (nextCut == len(text) or text[nextCut] == " "):
                while text[nextCut] != " ":
                    nextCut += 1

            line = text[cut:nextCut].strip()

            # is line still fitting ?
            w, h = draw.textsize(line, font)
            if not isLast and w > img.width:
                nextCut -= 1
                while text[nextCut] != " ":
                    nextCut -= 1

            lastCut = nextCut
            lines.append(text[cut:nextCut].strip())
    else:
        lines.append(text)

    lastY = -h
    if pos == "bottom":
        lastY = img.height - h * (lineCount+1) - 10

    for i in range(0, lineCount):
        w, h = draw.textsize(lines[i], font)
        x = img.width/2 - w/2
        y = lastY + h
        drawTextWithOutline(lines[i], x, y)
        lastY = y

def display_image_in_actual_size(im_path, dpi):
  im_data = plt.imread(im_path)
  height, width, depth = im_data.shape
  figsize = width / float(dpi), height / float(dpi)
  fig = plt.figure(figsize=figsize)
  ax = fig.add_axes([0, 0, 1, 1])
  ax.axis('off')
  ax.imshow(im_data)
  plt.show()

    
    
    
    
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw
import matplotlib.pyplot as plt

# from https://blog.lipsumarium.com/caption-memes-in-python/
text_query = 'panda'
choose_caption = "When you realize you're about to graduate and still don't have a job."
font_size= 34 #@param {type:"slider", min:20, max:60, step:2}
position = "bottom" #@param ["top", "bottom"]
# image_id = annotations[text_indices[image_indices[0]]][0]
# parts = image_id.split("/")

# file_name = all_image_metadata[image_indices[choose_image-1]][1]
choose_image = '/content/WhatsApp Image 2023-01-31 at 9.51.43 PM.jpeg'
img = Image.open(r'/content/WhatsApp Image 2023-01-31 at 9.51.43 PM.jpeg')
w, h = img.size
if (w > h):
  new_w = 512.0
  new_h = round(new_w * h / w)
else:
  new_h = 512.0
  new_w = round(new_h * w / h)
img = img.resize((int(new_w+0.5), int(new_h+0.5)))
img = img.convert(mode="RGB")
draw = ImageDraw.Draw(img)
font = ImageFont.truetype("impact.ttf", font_size)
drawText(choose_caption, position)
# print(x)
# output_filename = "AI-Memer_" + text_query.replace(" ", "_")
# output_filename += "_" + str(choose_image) + "_" + str(choose_caption) + ".jpg"
img.save('/content/out.jpg')
display_image_in_actual_size('/content/out.jpg', 72)
# author = all_image_metadata[image_indices[choose_image-1]][3]
# print("Meme by AI-Memer, Image by " + 'rishabh' + ", Caption by " + ai_engine + ", License: CC BY-SA 4.0")
